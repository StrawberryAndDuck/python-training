# %%
# 라이브러리 불러오기
import pandas as pd

# 데이터프레임 만들기
df1 = pd.DataFrame({'a': ['a0', 'a1', 'a2', 'a3'],
                    'b': ['b0', 'b1', 'b2', 'b3'],
                    'c': ['c0', 'c1', 'c2', 'c3']},
                    index=[0, 1, 2, 3])

print(df1)

# 시리즈 데이터 타입 확인
print(type(df1['a']))
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# <class 'pandas.core.series.Series'>

# %%
df2 = pd.DataFrame({'a': ['a2', 'a3', 'a4', 'a5'],
                    'b': ['b2', 'b3', 'b4', 'b5'],
                    'c': ['c2', 'c3', 'c4', 'c5'],
                    'd': ['d2', 'd3', 'd4', 'd5']},
                    index=[2, 3, 4, 5])

df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
# 2개의 데이터프레임을 행 방향으로 1개의 데이터프레임 만들기
result1 = pd.concat([df1, df2])
print(result1)

# ignore_index=True 옵션 설정하기
result2 = pd.concat([df1, df2], ignore_index=True)
print(result2)

# join='inner' 옵션 적용하기(교집합)
result2_in = pd.concat([df1, df2], axis=0, join= 'inner')
print(result2_in)

# 2개의 데이터프레임을 좌우 열 방향으로 1개의 데이터프레임 만들기
result3 = pd.concat([df1, df2], axis=1)
print(result3)

# join='inner' 옵션 적용하기(교집합)
result3_in = pd.concat([df1, df2], axis=1, join='inner')
print(result3_in)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 4  a2  b2  c2   d2
# 5  a3  b3  c3   d3
# 6  a4  b4  c4   d4
# 7  a5  b5  c5   d5
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5
#     a   b   c   a   b   c   d
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %%
# 시리즈 만들기
sr1 = pd.Series(['e0', 'e1', 'e2', 'e3'], name='e')
sr2 = pd.Series(['f0', 'f1', 'f2'], name='f', index=[3, 4, 5])
sr3 = pd.Series(['g0', 'g1', 'g2', 'g3'], name='g')
sr4 = pd.Series(['a6', 'b6', 'c6', 'd6'], index=['a', 'b', 'c', 'd'])

# # df1과 sr1을 좌우 열 방향으로 연결하기
# result4 = pd.concat([df1, sr1], axis=1)
# print(df1)
# print(sr1)
# print(result4)

# #df2과 sr2을 좌우 열 방향으로 연결하기
# result5 = pd.concat([df2, sr2], axis=1)
# print(df2)
# print(sr2)
# print(result5)

# df2, sr4 열기반 데이터프레임 민들기
result6 = pd.concat([df2, sr4.to_frame().T], ignore_index=True)
result7 = pd.concat([df2, sr4.to_frame()], ignore_index=False)
print(df2)
print(sr4)
print(result6)
print(result7)

# sr1, sr3을 열기반 데이터프레임 만들기
result7 = pd.concat([sr1, sr3], axis=1)
result7

# sr1, sr3 행기반 데이터프레임 만들기
result8 = pd.concat([sr1, sr3], axis=0, ignore_index=False)
result8
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# a    a6
# b    b6
# c    c6
# d    d6
# dtype: object
#     a   b   c   d
# 0  a2  b2  c2  d2
# 1  a3  b3  c3  d3
# 2  a4  b4  c4  d4
# 3  a5  b5  c5  d5
# 4  a6  b6  c6  d6
#      a    b    c    d    0
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 4   a4   b4   c4   d4  NaN
# 5   a5   b5   c5   d5  NaN
# a  NaN  NaN  NaN  NaN   a6
# b  NaN  NaN  NaN  NaN   b6
# c  NaN  NaN  NaN  NaN   c6
# d  NaN  NaN  NaN  NaN   d6
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# dtype: object
